# %%
lst = ['a', 'b', 'c', 'd', 'e', 'f']
print(lst)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %%
lst[5]
# Out:
# 'f'

# %%
len(lst)
# Out:
# 6

# %%
lst[3]
# Out:
# 'd'

# %%
lst[1:4]
# Out:
# ['b', 'c', 'd']

# %%
lst[:4]
# Out:
# ['a', 'b', 'c', 'd']

# %%
lst[2:]
# Out:
# ['c', 'd', 'e', 'f']

# %%
lst[len(lst)-1]
# Out:
# 'f'

# %%
lst[-1]
# Out:
# 'f'

# %%
lst[-2]
# Out:
# 'e'

# %%
lst[:-1]
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
lst[1:4:2]
# Out:
# ['b', 'd']

# %%
lst[::2]
# Out:
# ['a', 'c', 'e']

# %%
lst[::-1]
# Out:
# ['f', 'e', 'd', 'c', 'b', 'a']

# %% [markdown]
# Exercice: print the elements of an array in reverse order starting from the one before last

# %%
lst[-2::-1]
# Out:
# ['e', 'd', 'c', 'b', 'a']

# %%
lst
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %%
lst[-1]
# Out:
# 'f'

# %%
lst[-2]
# Out:
# 'e'
