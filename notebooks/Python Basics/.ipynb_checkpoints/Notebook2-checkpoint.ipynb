# %%
a = 1

# %%
lst = ['a', 1., '33.4']
print(lst)
# Out:
# ['a', 1.0, '33.4']

# %%
for item in lst:
    print(item)
print(item)
# Out:
# a
# 1.0
# 33.4
# 33.4

# %%
for i in range(3):
    print(i)
# Out:
# 0
# 1
# 2

# %%
for i in range(3):
    print(lst[i])
# Out:
# a
# 1.0
# 33.4

# %%
for i in range(0,3):
    print(i)
# Out:
# 0
# 1
# 2

# %%
for i in range(3,0,-2):
    print(i)
# Out:
# 3
# 1

# %%
for i, item in enumerate(lst):
    print(i, item)
# Out:
# 0 a
# 1 1.0
# 2 33.4

# %%
i = 0
while i<3:
    print(i)
    i = i + 1
print('finish')
# Out:
# 0
# 1
# 2
# finish

# %%
 1 <= 2
# Out:
# True

# %% [markdown]
# Exercice: write a loop that prints side-by-side the elements of a list in backward order from the one before last by step of 2 AND the index of the loop
