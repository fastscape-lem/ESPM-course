# %%
a = 20
print(a+1)
print(a-1)
print(a/2)
print(a*2)
print((-a)**0.5)
print(a//3)
print(a%3)
# Out:
# 21
# 19
# 10.0
# 40
# (2.7383934913210134e-16+4.47213595499958j)
# 6
# 2

# %%
a = 20
a /= 2
print(a)
# Out:
# 10.0

# %%
a = 20
a = a + 1
print(a)
# Out:
# 21

# %% [markdown]
# Exercice: compute the square of the ratio of two sums

# %%
print(((1+2)/(3+4))**2)
# Out:
# 0.18367346938775508
