# %%
a = 1 # this is an example of a number variable
another_number = 2
print(a + another_number)

# this is a comment

'''
This is a comment
on several lines
It is very useful for example to document
the input variables of a function
'''
# Out:
# 3

# %% [markdown]
# ### This is documentation
#
# $$\frac{\partial h}{\partial t}=K_D\nabla^2h$$

# %%
a = (
    1
     + 2
     + 3
     + 4
    )
print(a)
# Out:
# 10

# %%
n = 1/2
print(type(n))
a = [1,2,3]
print(a)
a[n]
# Out:
# <class 'float'>
# [1, 2, 3]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-d39b393aaff0> in <module>
#       3 a = [1,2,3]
#       4 print(a)
# ----> 5 a[n]
#
# TypeError: list indices must be integers or slices, not float

# %%
c = "How are you?"
b = "John"
print(c*2)
print(type(c))
# Out:
# How are you?How are you?
# <class 'str'>

# %%
tup = (2, 2.34, 'Hi', c)
print(tup)
# Out:
# (2, 2.34, 'Hi', 'How are you?')

# %%
tup[0] = 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-8004b63068db> in <module>
# ----> 1 tup[0] = 3
#
# TypeError: 'tuple' object does not support item assignment

# %%
lst = [2, 2.34, 'Hi', c]
print(lst[:])
# Out:
# [2, 2.34, 'Hi', 'How are you?']

# %%
lst[0]='Hi'
print(lst)
# Out:
# ['Hi', 2.34, 'Hi', 'How are you?']

# %%
dic = {'key1': [1,2,3], 'key2': 'John', 'key3': 2.345}

# %%
dic['key1']
# Out:
# [1, 2, 3]

# %%
calendar = {'Year': 1961, 'Month':'April', 'Day':21}

# %%
calendar['Year']
# Out:
# 1961
